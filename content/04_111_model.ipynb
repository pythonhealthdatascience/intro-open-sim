# %% [markdown]
# # A full SimPy model
#
# In this notebook, we will now build a full `simpy` process model. Our example is a queuing model of a 111 call centre.  We will include random arrivals and resources. We will keep this simple, and gradually add in detail and flexibility to our design.

# %% [markdown]
# ## 1. Imports

# %%
import simpy
import numpy as np
import itertools

# %% [markdown]
# ## 2. Problem background
#
# Call operators in an 111 (urgent care) service receive calls at a rate of 100 per hour. Call length can be represented by a triangular distribution.  Calls last between 5 minutes and 15 minutes. Most calls last 7 minutes. There are 13 call operators.
#
# ![Call Centre Diagram](../img/callcentre.png)

# %% [markdown]
# ## 3. SimPy resources
#
# To model the call centre, we need to introduce a **resource**.
#
# These resources represent the call operators. If a resource is not available then a process will **pause** (i.e. callers will wait for an operator to become available).
#
# We create a resource as follows:
#
# ```python
# operators = simpy.Resource(env, capacity=20)
# ```
#
# When we want to request a resource in our process, we create a `with` block as follows:
#
# ```python
# with operators.request() as req:
#     yield req
# ```
#
# This tells SimPy that **your process needs an operator resource to progress**.  The code will pause until a resource is yielded. This gives us our **queuing effect**.  If a resource is not available immediately then the process will wait until one becomes available.

# %% [markdown]
# ## 4. The service function
#
# We will first create a python function called `service()` to simulate the service process for a call operator. We need to include the following logic:
#
# 1. **Request and wait** (if necessary) for a call operator.
# 2. Undergo **phone triage** (a delay). This is a sample from the Triangular distribution.
# 3. **Exit the system**.
#
# Each caller that arrives in the simulation will this function as a SimPy **process**. As inputs to the function, we will pass:
#
# * A unique patient identifier (`identifier`)
# * A pool of operator resources (`operators`)
# * The environment (`env`)

# %%
def service(identifier, operators, env, service_rng):
    '''
    Simulates the service process for a call operator

    1. request and wait for a call operator
    2. phone triage (triangular)
    3. exit system
    
    Params:
    ------
    
    identifier: int 
        A unique identifer for this caller
        
    operators: simpy.Resource
        The pool of call operators that answer calls
        These are shared across resources.
        
    env: simpy.Environment
        The current environent the simulation is running in
        We use this to pause and restart the process after a delay.

    service_rng: numpy.random.Generator
        The random number generator used to sample service times
    
    '''
    # record the time that call entered the queue
    start_wait = env.now

    # request an operator
    with operators.request() as req:
        yield req

        # record the waiting time for call to be answered
        waiting_time = env.now - start_wait
        print(f'operator answered call {identifier} at ' \
              + f'{env.now:.3f}')

        # sample call duration.
        call_duration = service_rng.triangular(left=5.0, mode=7.0,
                                               right=10.0)
        
        # schedule process to begin again after call_duration
        yield env.timeout(call_duration)

        # print out information for patient.
        print(f'call {identifier} ended {env.now:.3f}; ' \
              + f'waiting time was {waiting_time:.3f}')

# %% [markdown]
# ## 5. The generator function
#
# The generator function is very similar to the [pharamacy example](./03b_exercise1_solutions.ipynb).
#
# > ✂️ **Notice the pattern**. For most models you can just cut, paste and modify code you have used before.

# %%
def arrivals_generator(env, operators):
    '''
    Inter-arrival time (IAT) is exponentially distributed

    Parameters:
    ------
    env: simpy.Environment
        The simpy environment for the simulation

    operators: simpy.Resource
        the pool of call operators.
    '''
    # create the arrival process rng 
    arrival_rng = np.random.default_rng()
    
    # create the service rng that we pass to each service process created
    service_rng = np.random.default_rng()
    
    # use itertools as it provides an infinite loop 
    # with a counter variable that we can use for unique Ids
    for caller_count in itertools.count(start=1):

        # 100 calls per hour (sim time units = minutes). 
        inter_arrival_time = arrival_rng.exponential(60/100)
        yield env.timeout(inter_arrival_time)

        print(f'call arrives at: {env.now:.3f}')

        # create a new simpy process for serving this caller.
        # we pass in the caller id, the operator resources, env, and the rng
        env.process(service(caller_count, operators, env, service_rng))

# %% [markdown]
# ## 6. Run the model

# %%
# model parameters
RUN_LENGTH = 100
N_OPERATORS = 13

# create simpy environment and operator resources
env = simpy.Environment()
operators = simpy.Resource(env, capacity=N_OPERATORS)

env.process(arrivals_generator(env, operators))
env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')
# Out:
# call arrives at: 0.118
# operator answered call 1 at 0.118
# call arrives at: 0.614
# operator answered call 2 at 0.614
# call arrives at: 1.317
# operator answered call 3 at 1.317
# call arrives at: 2.104
# operator answered call 4 at 2.104
# call arrives at: 2.737
# operator answered call 5 at 2.737
# call arrives at: 3.644
# operator answered call 6 at 3.644
# call arrives at: 3.868
# operator answered call 7 at 3.868
# call arrives at: 5.352
# operator answered call 8 at 5.352
# call arrives at: 5.840
# operator answered call 9 at 5.840
# call arrives at: 6.178
# operator answered call 10 at 6.178
# call arrives at: 6.197
# operator answered call 11 at 6.197
# call arrives at: 6.840
# operator answered call 12 at 6.840
# call 1 ended 7.194; waiting time was 0.000
# call 3 ended 7.692; waiting time was 0.000
# call 2 ended 7.901; waiting time was 0.000
# call arrives at: 8.351
# operator answered call 13 at 8.351
# call arrives at: 8.580
# operator answered call 14 at 8.580
# call arrives at: 8.604
# operator answered call 15 at 8.604
# call 4 ended 9.268; waiting time was 0.000
# call 5 ended 9.818; waiting time was 0.000
# call arrives at: 10.418
# operator answered call 16 at 10.418
# call 6 ended 10.434; waiting time was 0.000
# call arrives at: 10.582
# operator answered call 17 at 10.582
# call 7 ended 10.876; waiting time was 0.000
# call arrives at: 11.248
# operator answered call 18 at 11.248
# call arrives at: 11.282
# operator answered call 19 at 11.282
# call arrives at: 11.320
# operator answered call 20 at 11.320
# call arrives at: 11.331
# call arrives at: 11.567
# call arrives at: 12.358
# call 11 ended 12.845; waiting time was 0.000
# operator answered call 21 at 12.845
# call arrives at: 12.868
# call 12 ended 13.058; waiting time was 0.000
# operator answered call 22 at 13.058
# call arrives at: 13.163
# call 9 ended 13.271; waiting time was 0.000
# operator answered call 23 at 13.271
# call 8 ended 13.921; waiting time was 0.000
# operator answered call 24 at 13.921
# call 10 ended 14.062; waiting time was 0.000
# operator answered call 25 at 14.062
# call arrives at: 15.562
# call 13 ended 15.691; waiting time was 0.000
# operator answered call 26 at 15.691
# call arrives at: 15.711
# call arrives at: 16.083
# call 16 ended 16.260; waiting time was 0.000
# operator answered call 27 at 16.260
# call 15 ended 16.434; waiting time was 0.000
# operator answered call 28 at 16.434
# call arrives at: 16.664
# call 14 ended 17.447; waiting time was 0.000
# operator answered call 29 at 17.447
# call arrives at: 17.961
# call 18 ended 18.195; waiting time was 0.000
# operator answered call 30 at 18.195
# call arrives at: 18.215
# call 20 ended 18.393; waiting time was 0.000
# operator answered call 31 at 18.393
# call 19 ended 18.661; waiting time was 0.000
# call 17 ended 18.801; waiting time was 0.000
# call arrives at: 18.969
# operator answered call 32 at 18.969
# call 21 ended 19.464; waiting time was 1.513
# call arrives at: 20.137
# operator answered call 33 at 20.137
# call 24 ended 20.307; waiting time was 1.053
# call 22 ended 20.317; waiting time was 1.491
# call 23 ended 20.649; waiting time was 0.914
# call arrives at: 21.330
# operator answered call 34 at 21.330
# call 25 ended 21.358; waiting time was 0.899
# call arrives at: 21.906
# operator answered call 35 at 21.906
# call 28 ended 22.506; waiting time was 0.351
# call arrives at: 22.618
# operator answered call 36 at 22.618
# call 26 ended 22.716; waiting time was 0.129
# call arrives at: 22.816
# operator answered call 37 at 22.816
# call arrives at: 22.897
# operator answered call 38 at 22.897
# call arrives at: 22.960
# operator answered call 39 at 22.960
# call arrives at: 23.089
# operator answered call 40 at 23.089
# call 27 ended 23.706; waiting time was 0.549
# call arrives at: 24.263
# operator answered call 41 at 24.263
# call 29 ended 24.440; waiting time was 0.783
# call 30 ended 24.681; waiting time was 0.234
# call arrives at: 25.463
# operator answered call 42 at 25.463
# call 31 ended 25.802; waiting time was 0.178
# call 32 ended 26.132; waiting time was 0.000
# call 33 ended 26.241; waiting time was 0.000
# call arrives at: 26.269
# operator answered call 43 at 26.269
# call arrives at: 26.401
# operator answered call 44 at 26.401
# call arrives at: 27.569
# operator answered call 45 at 27.569
# call 36 ended 29.032; waiting time was 0.000
# call 34 ended 29.353; waiting time was 0.000
# call 39 ended 29.503; waiting time was 0.000
# call 35 ended 29.539; waiting time was 0.000
# call 38 ended 30.129; waiting time was 0.000
# call arrives at: 30.530
# operator answered call 46 at 30.530
# call 41 ended 30.997; waiting time was 0.000
# call 40 ended 31.695; waiting time was 0.000
# call 37 ended 31.889; waiting time was 0.000
# call arrives at: 32.165
# operator answered call 47 at 32.165
# call 42 ended 32.259; waiting time was 0.000
# call arrives at: 32.277
# operator answered call 48 at 32.277
# call 43 ended 33.373; waiting time was 0.000
# call 45 ended 34.133; waiting time was 0.000
# call 44 ended 34.334; waiting time was 0.000
# call arrives at: 35.479
# operator answered call 49 at 35.479
# call arrives at: 36.176
# operator answered call 50 at 36.176
# call arrives at: 36.395
# operator answered call 51 at 36.395
# call arrives at: 37.047
# operator answered call 52 at 37.047
# call arrives at: 37.339
# operator answered call 53 at 37.339
# call arrives at: 37.962
# operator answered call 54 at 37.962
# call 47 ended 38.950; waiting time was 0.000
# call 46 ended 39.282; waiting time was 0.000
# call 48 ended 39.729; waiting time was 0.000
# call arrives at: 40.452
# operator answered call 55 at 40.452
# call arrives at: 40.810
# operator answered call 56 at 40.810
# call 49 ended 40.890; waiting time was 0.000
# call arrives at: 40.915
# operator answered call 57 at 40.915
# call arrives at: 41.093
# operator answered call 58 at 41.093
# call arrives at: 41.615
# operator answered call 59 at 41.615
# call arrives at: 41.747
# operator answered call 60 at 41.747
# call arrives at: 41.825
# operator answered call 61 at 41.825
# call arrives at: 42.352
# operator answered call 62 at 42.352
# call arrives at: 42.480
# call 50 ended 42.965; waiting time was 0.000
# operator answered call 63 at 42.965
# call arrives at: 43.284
# call 54 ended 43.490; waiting time was 0.000
# operator answered call 64 at 43.490
# call 52 ended 43.665; waiting time was 0.000
# call 51 ended 44.021; waiting time was 0.000
# call arrives at: 44.609
# operator answered call 65 at 44.609
# call arrives at: 44.996
# operator answered call 66 at 44.996
# call 53 ended 45.329; waiting time was 0.000
# call arrives at: 45.449
# operator answered call 67 at 45.449
# call arrives at: 46.487
# call arrives at: 46.612
# call 58 ended 46.863; waiting time was 0.000
# operator answered call 68 at 46.863
# call 55 ended 47.556; waiting time was 0.000
# operator answered call 69 at 47.556
# call arrives at: 47.982
# call arrives at: 48.030
# call 57 ended 48.270; waiting time was 0.000
# operator answered call 70 at 48.270
# call arrives at: 48.290
# call arrives at: 48.320
# call arrives at: 48.422
# call 59 ended 48.477; waiting time was 0.000
# operator answered call 71 at 48.477
# call 62 ended 48.500; waiting time was 0.000
# operator answered call 72 at 48.500
# call arrives at: 48.550
# call arrives at: 48.624
# call 60 ended 48.693; waiting time was 0.000
# operator answered call 73 at 48.693
# call arrives at: 48.705
# call arrives at: 48.870
# call 61 ended 48.982; waiting time was 0.000
# operator answered call 74 at 48.982
# call arrives at: 49.177
# call arrives at: 49.453
# call 56 ended 49.917; waiting time was 0.000
# operator answered call 75 at 49.917
# call 63 ended 50.078; waiting time was 0.486
# operator answered call 76 at 50.078
# call 66 ended 50.515; waiting time was 0.000
# operator answered call 77 at 50.515
# call 65 ended 51.540; waiting time was 0.000
# operator answered call 78 at 51.540
# call arrives at: 51.634
# call arrives at: 52.081
# call 64 ended 52.575; waiting time was 0.206
# operator answered call 79 at 52.575
# call 68 ended 53.287; waiting time was 0.375
# operator answered call 80 at 53.287
# call arrives at: 53.531
# call arrives at: 53.586
# call 67 ended 53.849; waiting time was 0.000
# operator answered call 81 at 53.849
# call arrives at: 53.957
# call 70 ended 54.688; waiting time was 0.288
# operator answered call 82 at 54.688
# call 71 ended 54.706; waiting time was 0.447
# operator answered call 83 at 54.706
# call 69 ended 54.846; waiting time was 0.943
# operator answered call 84 at 54.846
# call arrives at: 54.942
# call arrives at: 55.055
# call arrives at: 55.802
# call arrives at: 55.844
# call arrives at: 56.297
# call 72 ended 56.307; waiting time was 0.210
# operator answered call 85 at 56.307
# call 73 ended 56.918; waiting time was 0.372
# operator answered call 86 at 56.918
# call 77 ended 57.284; waiting time was 1.810
# operator answered call 87 at 57.284
# call 74 ended 57.531; waiting time was 0.559
# operator answered call 88 at 57.531
# call arrives at: 57.689
# call 76 ended 57.801; waiting time was 1.453
# operator answered call 89 at 57.801
# call arrives at: 57.808
# call 75 ended 57.885; waiting time was 1.367
# operator answered call 90 at 57.885
# call 78 ended 57.891; waiting time was 2.670
# operator answered call 91 at 57.891
# call arrives at: 57.965
# call arrives at: 58.523
# call arrives at: 58.733
# call 79 ended 59.200; waiting time was 3.398
# operator answered call 92 at 59.200
# call arrives at: 59.680
# call arrives at: 59.778
# call arrives at: 59.938
# call arrives at: 60.426
# call 81 ended 61.594; waiting time was 2.215
# operator answered call 93 at 61.594
# call arrives at: 61.627
# call 80 ended 61.667; waiting time was 3.834
# operator answered call 94 at 61.667
# call arrives at: 61.788
# call 83 ended 62.619; waiting time was 1.174
# operator answered call 95 at 62.619
# call arrives at: 62.693
# call 87 ended 63.221; waiting time was 2.230
# operator answered call 96 at 63.221
# call 85 ended 63.249; waiting time was 2.350
# operator answered call 97 at 63.249
# call 86 ended 63.327; waiting time was 1.976
# operator answered call 98 at 63.327
# call arrives at: 63.404
# call 84 ended 63.511; waiting time was 1.260
# operator answered call 99 at 63.511
# call 89 ended 64.001; waiting time was 1.957
# operator answered call 100 at 64.001
# call arrives at: 64.174
# call 82 ended 64.428; waiting time was 2.607
# operator answered call 101 at 64.428
# call arrives at: 64.525
# call arrives at: 64.786
# call arrives at: 64.854
# call arrives at: 64.967
# call 92 ended 65.065; waiting time was 1.392
# operator answered call 102 at 65.065
# call arrives at: 65.287
# call 88 ended 65.928; waiting time was 1.729
# operator answered call 103 at 65.928
# call 90 ended 66.129; waiting time was 1.588
# operator answered call 104 at 66.129
# call 91 ended 66.409; waiting time was 0.202
# operator answered call 105 at 66.409
# call arrives at: 66.783
# call arrives at: 67.020
# call arrives at: 67.438
# call arrives at: 67.604
# call arrives at: 67.904
# call 93 ended 68.172; waiting time was 3.628
# operator answered call 106 at 68.172
# call arrives at: 68.194
# call arrives at: 68.693
# call arrives at: 69.149
# call 97 ended 69.441; waiting time was 3.471
# operator answered call 107 at 69.441
# call arrives at: 69.459
# call arrives at: 69.657
# call arrives at: 69.742
# call 95 ended 69.808; waiting time was 3.886
# operator answered call 108 at 69.808
# call arrives at: 69.827
# call arrives at: 69.939
# call arrives at: 70.054
# call arrives at: 70.118
# call 96 ended 70.195; waiting time was 3.542
# operator answered call 109 at 70.195
# call 100 ended 70.935; waiting time was 2.374
# operator answered call 110 at 70.935
# call 94 ended 70.980; waiting time was 3.143
# operator answered call 111 at 70.980
# call arrives at: 71.390
# call 99 ended 71.750; waiting time was 3.084
# operator answered call 112 at 71.750
# call 104 ended 72.300; waiting time was 1.955
# operator answered call 113 at 72.300
# call 98 ended 72.387; waiting time was 3.389
# operator answered call 114 at 72.387
# call 102 ended 72.543; waiting time was 2.372
# operator answered call 115 at 72.543
# call 105 ended 72.643; waiting time was 1.884
# operator answered call 116 at 72.643
# call arrives at: 72.898
# call 103 ended 73.297; waiting time was 2.524
# operator answered call 117 at 73.297
# call 101 ended 73.435; waiting time was 2.641
# operator answered call 118 at 73.435
# call arrives at: 75.254
# call 106 ended 75.651; waiting time was 3.386
# operator answered call 119 at 75.651
# call arrives at: 76.085
# call 109 ended 76.340; waiting time was 4.907
# operator answered call 120 at 76.340
# call 111 ended 76.781; waiting time was 3.960
# operator answered call 121 at 76.781
# call 107 ended 76.817; waiting time was 4.587
# operator answered call 122 at 76.817
# call arrives at: 76.870
# call 110 ended 78.181; waiting time was 4.152
# operator answered call 123 at 78.181
# call arrives at: 78.287
# call 108 ended 78.846; waiting time was 4.842
# operator answered call 124 at 78.846
# call 114 ended 78.976; waiting time was 4.483
# operator answered call 125 at 78.976
# call arrives at: 78.985
# call 115 ended 79.005; waiting time was 4.349
# operator answered call 126 at 79.005
# call arrives at: 79.054
# call 118 ended 79.213; waiting time was 3.976
# operator answered call 127 at 79.213
# call 116 ended 79.339; waiting time was 3.951
# operator answered call 128 at 79.339
# call 113 ended 80.374; waiting time was 4.697
# operator answered call 129 at 80.374
# call arrives at: 80.426
# call arrives at: 80.680
# call arrives at: 80.908
# call arrives at: 80.928
# call 117 ended 81.180; waiting time was 4.148
# operator answered call 130 at 81.180
# call 112 ended 81.291; waiting time was 4.312
# operator answered call 131 at 81.291
# call arrives at: 81.814
# call arrives at: 82.172
# call arrives at: 82.730
# call 121 ended 83.267; waiting time was 6.954
# operator answered call 132 at 83.267
# call arrives at: 83.565
# call arrives at: 83.623
# call arrives at: 83.656
# call arrives at: 84.274
# call 122 ended 84.901; waiting time was 6.879
# operator answered call 133 at 84.901
# call 125 ended 84.958; waiting time was 7.586
# operator answered call 134 at 84.958
# call 123 ended 85.066; waiting time was 8.127
# operator answered call 135 at 85.066
# call arrives at: 85.214
# call arrives at: 85.552
# call 119 ended 85.599; waiting time was 5.994
# operator answered call 136 at 85.599
# call 128 ended 85.782; waiting time was 3.254
# operator answered call 137 at 85.782
# call 120 ended 85.814; waiting time was 6.598
# operator answered call 138 at 85.814
# call 127 ended 86.793; waiting time was 3.959
# operator answered call 139 at 86.793
# call arrives at: 87.072
# call 126 ended 87.338; waiting time was 6.107
# operator answered call 140 at 87.338
# call 129 ended 87.448; waiting time was 3.504
# operator answered call 141 at 87.448
# call 130 ended 87.610; waiting time was 2.893
# operator answered call 142 at 87.610
# call arrives at: 87.727
# call arrives at: 88.137
# call arrives at: 88.238
# call arrives at: 88.404
# call 124 ended 88.514; waiting time was 8.728
# operator answered call 143 at 88.514
# call 131 ended 88.925; waiting time was 2.305
# operator answered call 144 at 88.925
# call arrives at: 88.940
# call arrives at: 89.600
# call arrives at: 90.119
# call arrives at: 90.432
# call 132 ended 90.438; waiting time was 4.213
# operator answered call 145 at 90.438
# call 137 ended 91.437; waiting time was 3.968
# operator answered call 146 at 91.437
# call arrives at: 91.846
# call 138 ended 91.851; waiting time was 3.641
# operator answered call 147 at 91.851
# call arrives at: 92.344
# call arrives at: 92.533
# call 134 ended 92.656; waiting time was 4.278
# operator answered call 148 at 92.656
# call 135 ended 92.967; waiting time was 4.158
# operator answered call 149 at 92.967
# call 136 ended 93.244; waiting time was 4.671
# operator answered call 150 at 93.244
# call 133 ended 94.006; waiting time was 4.475
# operator answered call 151 at 94.006
# call arrives at: 94.153
# call 142 ended 94.189; waiting time was 3.954
# operator answered call 152 at 94.189
# call 141 ended 94.238; waiting time was 3.825
# operator answered call 153 at 94.238
# call arrives at: 94.780
# call 140 ended 95.066; waiting time was 3.773
# operator answered call 154 at 95.066
# call 143 ended 95.542; waiting time was 4.240
# operator answered call 155 at 95.542
# call 139 ended 95.571; waiting time was 4.063
# operator answered call 156 at 95.571
# call 144 ended 96.254; waiting time was 3.711
# operator answered call 157 at 96.254
# call arrives at: 96.653
# call arrives at: 98.142
# call arrives at: 98.381
# call 147 ended 98.497; waiting time was 4.124
# operator answered call 158 at 98.497
# call 146 ended 99.290; waiting time was 4.365
# operator answered call 159 at 99.290
# call 148 ended 99.445; waiting time was 4.519
# operator answered call 160 at 99.445
# call arrives at: 99.704
# call 145 ended 99.778; waiting time was 4.886
# operator answered call 161 at 99.778
# end of run. simulation clock time = 100
