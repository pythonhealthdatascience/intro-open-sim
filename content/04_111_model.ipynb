# %% [markdown]
# # A full SimPy model
#
# In this notebook, we will now build a full `simpy` process model. Our example is a queuing model of a 111 call centre.  We will include random arrivals and resources. We will keep this simple, and gradually add in detail and flexibility to our design.

# %% [markdown]
# ## 1. Imports

# %%
import simpy
import numpy as np
import itertools

# %% [markdown]
# ## 2. Problem background
#
# Call operators in an 111 (urgent care) service receive calls at a rate of 100 per hour. Call length can be represented by a triangular distribution.  Calls last between 5 minutes and 15 minutes. Most calls last 7 minutes. There are 13 call operators.
#
# ![Call Centre Diagram](./img/callcentre.png)

# %% [markdown]
# ## 3. SimPy resources
#
# To model the call centre, we need to introduce a **resource**.
#
# These resources represent the call operators. If a resource is not available then a process will **pause** (i.e. callers will wait for an operator to become available).
#
# We create a resource as follows:
#
# ```python
# operators = simpy.Resource(env, capacity=20)
# ```
#
# When we want to request a resource in our process, we create a `with` block as follows:
#
# ```python
# with operators.request() as req:
#     yield req
# ```
#
# This tells SimPy that **your process needs an operator resource to progress**.  The code will pause until a resource is yielded. This gives us our **queuing effect**.  If a resource is not available immediately then the process will wait until one becomes available.

# %% [markdown]
# ## 4. The service function
#
# We will first create a python function called `service()` to simulate the service process for a call operator. We need to include the following logic:
#
# 1. **Request and wait** (if necessary) for a call operator.
# 2. Undergo **phone triage** (a delay). This is a sample from the Triangular distribution.
# 3. **Exit the system**.
#
# Each caller that arrives in the simulation will this function as a SimPy **process**. As inputs to the function, we will pass:
#
# * A unique patient identifier (`identifier`)
# * A pool of operator resources (`operators`)
# * The environment (`env`)
# * The service process random number generator object (`service_rng`)

# %%
def service(identifier, operators, env, service_rng):
    '''
    Simulates the service process for a call operator

    1. request and wait for a call operator
    2. phone triage (triangular)
    3. exit system
    
    Params:
    ------
    
    identifier: int 
        A unique identifer for this caller
        
    operators: simpy.Resource
        The pool of call operators that answer calls
        These are shared across resources.
        
    env: simpy.Environment
        The current environent the simulation is running in
        We use this to pause and restart the process after a delay.

    service_rng: numpy.random.Generator
        The random number generator used to sample service times
    
    '''
    start_wait = env.now

    with operators.request() as req:
        yield req

        waiting_time = env.now - start_wait
        print(f'operator answered call {identifier} at {env.now:.2f}')

        call_duration = service_rng.triangular(left=5.0, mode=7.0, right=10.0)
        yield env.timeout(call_duration)

        print(f'call {identifier} ended {env.now:.2f}; ' \
              + f'waiting time was {waiting_time:.2f}')

# %% [markdown]
# ## 5. The generator function
#
# The generator function is very similar to the [our initial
# code](./03b_exercise1_solutions.ipynb).
#
# > ✂️ **Notice the pattern**. For most models you can just cut, paste and modify code you have used before.

# %%
def arrivals_generator(env, operators):
    '''
    Simulates the call arrival process and spawns 
    Inter-arrival time (IAT) is exponentially distributed

    Parameters:
    ------
    env: simpy.Environment
        The simpy environment for the simulation
    '''
    arrivals_rng = np.random.default_rng()

    service_rng = np.random.default_rng()
   
    for caller_count in itertools.count(start=1):
        inter_arrival_time = arrivals_rng.exponential(60.0/100.0)
        yield env.timeout(inter_arrival_time)
        print(f'Call arrives at: {env.now:.2f}')

        env.process(service(caller_count, operators, env, service_rng))

# %% [markdown]
# ## 6. Run the model

# %%
# model parameters
RUN_LENGTH = 100
N_OPERATORS = 13

# create simpy environment and operator resources
env = simpy.Environment()
operators = simpy.Resource(env, capacity=N_OPERATORS)

env.process(arrivals_generator(env, operators))
env.run(until=RUN_LENGTH)
print(f'end of run. simulation clock time = {env.now}')
# Out:
# Call arrives at: 0.01
# operator answered call 1 at 0.01
# Call arrives at: 1.42
# operator answered call 2 at 1.42
# Call arrives at: 2.74
# operator answered call 3 at 2.74
# Call arrives at: 4.55
# operator answered call 4 at 4.55
# Call arrives at: 5.08
# operator answered call 5 at 5.08
# Call arrives at: 6.78
# operator answered call 6 at 6.78
# call 1 ended 6.95; waiting time was 0.00
# Call arrives at: 7.24
# operator answered call 7 at 7.24
# call 2 ended 7.88; waiting time was 0.00
# Call arrives at: 9.33
# operator answered call 8 at 9.33
# Call arrives at: 9.47
# operator answered call 9 at 9.47
# Call arrives at: 9.54
# operator answered call 10 at 9.54
# Call arrives at: 10.05
# operator answered call 11 at 10.05
# Call arrives at: 10.93
# operator answered call 12 at 10.93
# Call arrives at: 11.27
# operator answered call 13 at 11.27
# call 4 ended 11.52; waiting time was 0.00
# call 5 ended 11.54; waiting time was 0.00
# Call arrives at: 11.90
# operator answered call 14 at 11.90
# Call arrives at: 12.04
# operator answered call 15 at 12.04
# call 3 ended 12.27; waiting time was 0.00
# Call arrives at: 12.39
# operator answered call 16 at 12.39
# Call arrives at: 12.84
# operator answered call 17 at 12.84
# Call arrives at: 13.04
# operator answered call 18 at 13.04
# Call arrives at: 13.83
# call 7 ended 13.99; waiting time was 0.00
# operator answered call 19 at 13.99
# call 6 ended 14.30; waiting time was 0.00
# Call arrives at: 14.36
# operator answered call 20 at 14.36
# Call arrives at: 14.55
# Call arrives at: 16.39
# call 10 ended 16.40; waiting time was 0.00
# operator answered call 21 at 16.40
# Call arrives at: 16.57
# Call arrives at: 16.75
# call 16 ended 17.59; waiting time was 0.00
# operator answered call 22 at 17.59
# call 12 ended 17.88; waiting time was 0.00
# operator answered call 23 at 17.88
# call 8 ended 17.89; waiting time was 0.00
# operator answered call 24 at 17.89
# call 9 ended 18.03; waiting time was 0.00
# Call arrives at: 18.10
# operator answered call 25 at 18.10
# call 15 ended 18.13; waiting time was 0.00
# Call arrives at: 18.93
# operator answered call 26 at 18.93
# call 11 ended 19.16; waiting time was 0.00
# call 13 ended 19.19; waiting time was 0.00
# call 17 ended 19.37; waiting time was 0.00
# call 18 ended 19.38; waiting time was 0.00
# Call arrives at: 19.75
# operator answered call 27 at 19.75
# Call arrives at: 20.12
# operator answered call 28 at 20.12
# call 19 ended 20.42; waiting time was 0.16
# call 14 ended 20.46; waiting time was 0.00
# call 20 ended 20.63; waiting time was 0.00
# Call arrives at: 20.70
# operator answered call 29 at 20.70
# Call arrives at: 21.48
# operator answered call 30 at 21.48
# Call arrives at: 22.43
# operator answered call 31 at 22.43
# Call arrives at: 22.97
# operator answered call 32 at 22.97
# call 21 ended 23.01; waiting time was 1.85
# call 25 ended 23.48; waiting time was 0.00
# call 23 ended 24.13; waiting time was 1.32
# Call arrives at: 24.74
# operator answered call 33 at 24.74
# call 26 ended 24.91; waiting time was 0.00
# call 24 ended 25.49; waiting time was 1.15
# call 29 ended 26.27; waiting time was 0.00
# call 22 ended 26.48; waiting time was 1.19
# Call arrives at: 26.65
# operator answered call 34 at 26.65
# Call arrives at: 26.71
# operator answered call 35 at 26.71
# call 27 ended 26.99; waiting time was 0.00
# call 28 ended 27.46; waiting time was 0.00
# Call arrives at: 27.67
# operator answered call 36 at 27.67
# Call arrives at: 28.32
# operator answered call 37 at 28.32
# call 30 ended 28.32; waiting time was 0.00
# call 31 ended 28.36; waiting time was 0.00
# Call arrives at: 29.41
# operator answered call 38 at 29.41
# Call arrives at: 30.00
# operator answered call 39 at 30.00
# Call arrives at: 30.13
# operator answered call 40 at 30.13
# Call arrives at: 30.27
# operator answered call 41 at 30.27
# call 33 ended 31.32; waiting time was 0.00
# call 32 ended 31.36; waiting time was 0.00
# Call arrives at: 31.61
# operator answered call 42 at 31.61
# Call arrives at: 31.63
# operator answered call 43 at 31.63
# Call arrives at: 32.56
# operator answered call 44 at 32.56
# call 34 ended 33.80; waiting time was 0.00
# Call arrives at: 33.81
# operator answered call 45 at 33.81
# call 36 ended 34.67; waiting time was 0.00
# call 35 ended 34.72; waiting time was 0.00
# Call arrives at: 34.86
# operator answered call 46 at 34.86
# Call arrives at: 35.57
# operator answered call 47 at 35.57
# Call arrives at: 36.25
# operator answered call 48 at 36.25
# call 38 ended 36.43; waiting time was 0.00
# Call arrives at: 36.49
# operator answered call 49 at 36.49
# Call arrives at: 36.54
# operator answered call 50 at 36.54
# call 41 ended 36.73; waiting time was 0.00
# call 37 ended 36.94; waiting time was 0.00
# Call arrives at: 37.09
# operator answered call 51 at 37.09
# call 40 ended 37.23; waiting time was 0.00
# call 39 ended 37.36; waiting time was 0.00
# Call arrives at: 37.77
# operator answered call 52 at 37.77
# Call arrives at: 38.03
# operator answered call 53 at 38.03
# call 43 ended 38.64; waiting time was 0.00
# call 44 ended 38.69; waiting time was 0.00
# call 42 ended 39.50; waiting time was 0.00
# Call arrives at: 39.53
# operator answered call 54 at 39.53
# Call arrives at: 40.52
# operator answered call 55 at 40.52
# Call arrives at: 41.31
# operator answered call 56 at 41.31
# Call arrives at: 41.32
# operator answered call 57 at 41.32
# Call arrives at: 41.61
# call 45 ended 42.17; waiting time was 0.00
# operator answered call 58 at 42.17
# Call arrives at: 42.29
# Call arrives at: 42.54
# Call arrives at: 42.72
# Call arrives at: 42.79
# call 46 ended 42.82; waiting time was 0.00
# operator answered call 59 at 42.82
# call 51 ended 43.39; waiting time was 0.00
# operator answered call 60 at 43.39
# call 49 ended 43.42; waiting time was 0.00
# operator answered call 61 at 43.42
# call 53 ended 43.62; waiting time was 0.00
# operator answered call 62 at 43.62
# call 47 ended 43.70; waiting time was 0.00
# Call arrives at: 44.10
# operator answered call 63 at 44.10
# call 48 ended 44.81; waiting time was 0.00
# call 52 ended 44.87; waiting time was 0.00
# call 50 ended 44.91; waiting time was 0.00
# Call arrives at: 45.24
# operator answered call 64 at 45.24
# Call arrives at: 45.56
# operator answered call 65 at 45.56
# Call arrives at: 45.68
# operator answered call 66 at 45.68
# Call arrives at: 45.94
# Call arrives at: 46.38
# call 54 ended 46.75; waiting time was 0.00
# operator answered call 67 at 46.75
# Call arrives at: 46.94
# Call arrives at: 47.06
# Call arrives at: 47.65
# call 55 ended 47.66; waiting time was 0.00
# operator answered call 68 at 47.66
# Call arrives at: 47.78
# call 57 ended 47.83; waiting time was 0.00
# operator answered call 69 at 47.83
# call 56 ended 48.43; waiting time was 0.00
# operator answered call 70 at 48.43
# Call arrives at: 48.48
# Call arrives at: 48.93
# Call arrives at: 49.23
# Call arrives at: 49.40
# call 59 ended 49.53; waiting time was 0.53
# operator answered call 71 at 49.53
# Call arrives at: 49.60
# Call arrives at: 49.62
# call 61 ended 49.80; waiting time was 0.71
# operator answered call 72 at 49.80
# call 62 ended 50.01; waiting time was 0.83
# operator answered call 73 at 50.01
# Call arrives at: 50.16
# call 63 ended 50.29; waiting time was 0.00
# operator answered call 74 at 50.29
# call 60 ended 50.71; waiting time was 0.85
# operator answered call 75 at 50.71
# Call arrives at: 51.05
# Call arrives at: 51.08
# call 58 ended 51.31; waiting time was 0.56
# operator answered call 76 at 51.31
# Call arrives at: 51.76
# Call arrives at: 52.08
# call 64 ended 52.33; waiting time was 0.00
# operator answered call 77 at 52.33
# Call arrives at: 52.42
# Call arrives at: 52.61
# call 65 ended 53.31; waiting time was 0.00
# operator answered call 78 at 53.31
# call 69 ended 53.97; waiting time was 0.89
# operator answered call 79 at 53.97
# Call arrives at: 54.74
# call 68 ended 55.01; waiting time was 1.28
# operator answered call 80 at 55.01
# call 70 ended 55.10; waiting time was 1.37
# operator answered call 81 at 55.10
# call 66 ended 55.27; waiting time was 0.00
# operator answered call 82 at 55.27
# call 73 ended 55.68; waiting time was 1.54
# operator answered call 83 at 55.68
# call 67 ended 55.84; waiting time was 0.81
# operator answered call 84 at 55.84
# Call arrives at: 56.18
# call 74 ended 56.27; waiting time was 1.36
# operator answered call 85 at 56.27
# Call arrives at: 56.40
# Call arrives at: 56.68
# call 72 ended 57.07; waiting time was 2.02
# operator answered call 86 at 57.07
# call 75 ended 57.58; waiting time was 1.48
# operator answered call 87 at 57.58
# call 71 ended 57.73; waiting time was 1.88
# operator answered call 88 at 57.73
# call 76 ended 58.22; waiting time was 1.91
# operator answered call 89 at 58.22
# Call arrives at: 58.84
# Call arrives at: 58.88
# call 77 ended 60.19; waiting time was 2.73
# operator answered call 90 at 60.19
# Call arrives at: 60.42
# call 78 ended 60.51; waiting time was 3.69
# operator answered call 91 at 60.51
# call 79 ended 60.70; waiting time was 3.81
# operator answered call 92 at 60.70
# Call arrives at: 61.07
# Call arrives at: 61.77
# Call arrives at: 61.80
# call 81 ended 62.28; waiting time was 4.02
# operator answered call 93 at 62.28
# call 80 ended 62.66; waiting time was 3.96
# operator answered call 94 at 62.66
# call 85 ended 62.66; waiting time was 3.66
# operator answered call 95 at 62.66
# Call arrives at: 62.74
# Call arrives at: 62.84
# Call arrives at: 63.60
# Call arrives at: 63.73
# call 84 ended 63.93; waiting time was 3.41
# operator answered call 96 at 63.93
# Call arrives at: 63.99
# call 83 ended 64.05; waiting time was 3.61
# operator answered call 97 at 64.05
# call 86 ended 64.09; waiting time was 2.34
# operator answered call 98 at 64.09
# call 82 ended 64.40; waiting time was 3.51
# operator answered call 99 at 64.40
# Call arrives at: 64.69
# call 88 ended 64.78; waiting time was 1.33
# operator answered call 100 at 64.78
# Call arrives at: 64.82
# Call arrives at: 64.95
# call 87 ended 65.28; waiting time was 1.40
# operator answered call 101 at 65.28
# Call arrives at: 65.57
# Call arrives at: 66.06
# call 92 ended 66.15; waiting time was 0.28
# operator answered call 102 at 66.15
# Call arrives at: 66.44
# call 91 ended 66.88; waiting time was 1.63
# operator answered call 103 at 66.88
# call 89 ended 66.91; waiting time was 1.54
# operator answered call 104 at 66.91
# Call arrives at: 66.97
# Call arrives at: 67.19
# Call arrives at: 67.34
# call 93 ended 68.57; waiting time was 1.21
# operator answered call 105 at 68.57
# Call arrives at: 68.72
# call 90 ended 68.75; waiting time was 1.35
# operator answered call 106 at 68.75
# Call arrives at: 69.17
# Call arrives at: 69.44
# call 94 ended 69.61; waiting time was 0.89
# operator answered call 107 at 69.61
# call 98 ended 69.85; waiting time was 0.49
# operator answered call 108 at 69.85
# call 95 ended 69.90; waiting time was 0.87
# operator answered call 109 at 69.90
# Call arrives at: 70.42
# call 97 ended 70.59; waiting time was 1.22
# operator answered call 110 at 70.59
# Call arrives at: 70.86
# call 99 ended 71.12; waiting time was 0.67
# operator answered call 111 at 71.12
# Call arrives at: 71.33
# Call arrives at: 71.66
# Call arrives at: 71.76
# call 96 ended 71.90; waiting time was 1.19
# operator answered call 112 at 71.90
# call 100 ended 72.00; waiting time was 0.79
# operator answered call 113 at 72.00
# Call arrives at: 72.17
# call 102 ended 72.38; waiting time was 1.33
# operator answered call 114 at 72.38
# Call arrives at: 72.47
# call 101 ended 73.68; waiting time was 0.60
# operator answered call 115 at 73.68
# call 104 ended 74.15; waiting time was 1.34
# operator answered call 116 at 74.15
# call 103 ended 74.43; waiting time was 1.93
# operator answered call 117 at 74.43
# Call arrives at: 74.78
# call 106 ended 74.80; waiting time was 2.31
# operator answered call 118 at 74.80
# Call arrives at: 74.98
# call 105 ended 75.22; waiting time was 2.51
# operator answered call 119 at 75.22
# Call arrives at: 75.32
# call 107 ended 75.79; waiting time was 2.64
# operator answered call 120 at 75.79
# Call arrives at: 76.05
# call 110 ended 76.07; waiting time was 1.87
# operator answered call 121 at 76.07
# call 109 ended 76.36; waiting time was 2.55
# operator answered call 122 at 76.36
# Call arrives at: 76.91
# call 108 ended 78.31; waiting time was 2.66
# operator answered call 123 at 78.31
# Call arrives at: 78.40
# call 114 ended 78.85; waiting time was 1.52
# operator answered call 124 at 78.85
# Call arrives at: 79.07
# Call arrives at: 79.14
# call 112 ended 79.28; waiting time was 2.45
# operator answered call 125 at 79.28
# call 111 ended 79.33; waiting time was 1.95
# operator answered call 126 at 79.33
# Call arrives at: 79.34
# Call arrives at: 79.92
# call 117 ended 80.38; waiting time was 2.67
# operator answered call 127 at 80.38
# Call arrives at: 80.40
# call 116 ended 80.62; waiting time was 2.50
# operator answered call 128 at 80.62
# call 115 ended 80.68; waiting time was 2.35
# operator answered call 129 at 80.68
# Call arrives at: 80.75
# call 113 ended 80.78; waiting time was 1.57
# operator answered call 130 at 80.78
# call 119 ended 80.83; waiting time was 2.74
# operator answered call 131 at 80.83
# Call arrives at: 81.54
# Call arrives at: 81.96
# Call arrives at: 81.96
# Call arrives at: 82.01
# call 120 ended 82.24; waiting time was 1.01
# operator answered call 132 at 82.24
# Call arrives at: 82.35
# call 118 ended 82.51; waiting time was 2.63
# operator answered call 133 at 82.51
# call 121 ended 82.74; waiting time was 1.09
# operator answered call 134 at 82.74
# Call arrives at: 83.03
# call 122 ended 83.06; waiting time was 1.04
# operator answered call 135 at 83.06
# Call arrives at: 85.11
# call 123 ended 85.44; waiting time was 2.26
# operator answered call 136 at 85.44
# call 127 ended 86.05; waiting time was 1.24
# operator answered call 137 at 86.05
# call 125 ended 86.07; waiting time was 0.88
# operator answered call 138 at 86.07
# Call arrives at: 86.78
# Call arrives at: 87.16
# call 126 ended 87.41; waiting time was 0.26
# operator answered call 139 at 87.41
# Call arrives at: 87.64
# Call arrives at: 87.80
# call 128 ended 87.94; waiting time was 1.29
# operator answered call 140 at 87.94
# Call arrives at: 88.01
# Call arrives at: 88.01
# call 131 ended 88.22; waiting time was 0.08
# operator answered call 141 at 88.22
# call 129 ended 88.36; waiting time was 0.76
# operator answered call 142 at 88.36
# Call arrives at: 88.43
# call 124 ended 88.62; waiting time was 1.95
# operator answered call 143 at 88.62
# Call arrives at: 88.68
# Call arrives at: 88.81
# Call arrives at: 88.92
# call 132 ended 89.18; waiting time was 0.69
# operator answered call 144 at 89.18
# call 130 ended 89.28; waiting time was 0.38
# operator answered call 145 at 89.28
# Call arrives at: 89.41
# call 133 ended 89.72; waiting time was 0.55
# operator answered call 146 at 89.72
# call 134 ended 90.03; waiting time was 0.78
# operator answered call 147 at 90.03
# Call arrives at: 90.20
# Call arrives at: 90.55
# Call arrives at: 90.64
# Call arrives at: 90.80
# call 135 ended 90.80; waiting time was 1.05
# operator answered call 148 at 90.80
# Call arrives at: 90.90
# call 136 ended 91.13; waiting time was 3.09
# operator answered call 149 at 91.13
# Call arrives at: 91.56
# call 138 ended 93.11; waiting time was 0.96
# operator answered call 150 at 93.11
# Call arrives at: 93.34
# Call arrives at: 93.58
# Call arrives at: 93.64
# call 137 ended 93.65; waiting time was 3.02
# operator answered call 151 at 93.65
# Call arrives at: 94.11
# call 143 ended 94.46; waiting time was 0.62
# operator answered call 152 at 94.46
# Call arrives at: 94.78
# call 139 ended 95.23; waiting time was 0.63
# operator answered call 153 at 95.23
# Call arrives at: 95.28
# call 142 ended 95.51; waiting time was 0.56
# operator answered call 154 at 95.51
# call 141 ended 95.67; waiting time was 0.58
# operator answered call 155 at 95.67
# call 144 ended 95.84; waiting time was 1.17
# operator answered call 156 at 95.84
# call 140 ended 96.57; waiting time was 0.79
# operator answered call 157 at 96.57
# call 146 ended 96.80; waiting time was 1.04
# operator answered call 158 at 96.80
# call 145 ended 97.15; waiting time was 0.85
# operator answered call 159 at 97.15
# Call arrives at: 97.84
# Call arrives at: 98.18
# Call arrives at: 98.32
# call 147 ended 98.38; waiting time was 1.22
# operator answered call 160 at 98.38
# call 150 ended 98.54; waiting time was 2.91
# operator answered call 161 at 98.54
# Call arrives at: 98.63
# Call arrives at: 98.66
# call 149 ended 99.07; waiting time was 1.72
# operator answered call 162 at 99.07
# Call arrives at: 99.08
# Call arrives at: 99.12
# call 148 ended 99.57; waiting time was 1.88
# operator answered call 163 at 99.57
# Call arrives at: 99.80
# call 151 ended 99.84; waiting time was 3.10
# operator answered call 164 at 99.84
# end of run. simulation clock time = 100
